# %% [markdown]
# NAME: ALOK KUMAR MAVI
#
# SECTION: B
#
# ROLL.NO.: 05
#
# CU ID: CU240251681
#
# ##LAB SHEET - 01

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, MinMaxScaler

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("/workspaces/techprac/IBM-HR-Data-Preprocessing/data/WA_Fn-UseC_-HR-Employee-Attrition.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 1470
# Columns: 35

# %%
print(df.columns.tolist())
# Out:
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
missing_values = df.isnull().sum()

missing_values = missing_values[missing_values > 0]

print(missing_values)
# Out:
# Series([], dtype: int64)

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
df = df.drop_duplicates()

print("Duplicates after removal:", df.duplicated().sum())
# Out:
# Duplicates after removal: 0

# %%
categorical_columns = df.select_dtypes(include="str").columns
numerical_columns = df.select_dtypes(include=np.number).columns

print("Categorical columns:")
print(categorical_columns.tolist())

print("\nNumerical columns:")
print(numerical_columns.tolist())
# Out:
# Categorical columns:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
#
# Numerical columns:
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
print(categorical_columns.tolist())
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

# %%
df_encoded = pd.get_dummies(
    df,
    columns=categorical_columns,
    drop_first=True
)

# %%
df_encoded.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        2          94               3         2  ...
# 1                        3          61               2         2  ...
# 2                        4          92               2         1  ...
# 3                        4          56               3         1  ...
# 4                        1          40               3         1  ...
#
#    JobRole_Laboratory Technician  JobRole_Manager  \
# ...

# %%
print(df_encoded.shape)
# Out:
# (1470, 48)

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(x=df["MonthlyIncome"])

plt.title("Box Plot of Monthly Income")
plt.show()

# %%
Q1 = df["MonthlyIncome"].quantile(0.25)
Q3 = df["MonthlyIncome"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Q1: 2911.0
# Q3: 8379.0
# IQR: 5468.0
# Lower Bound: -5291.0
# Upper Bound: 16581.0

# %%
outliers = df[
    (df["MonthlyIncome"] < lower_bound) |
    (df["MonthlyIncome"] > upper_bound)
]

print("Number of outliers:", len(outliers))
# Out:
# Number of outliers: 114

# %%
df["MonthlyIncome"] = df["MonthlyIncome"].clip(
    lower=lower_bound,
    upper=upper_bound
)

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(x=df["MonthlyIncome"])

plt.title("Monthly Income After Outlier Treatment")
plt.show()

# %%
df_scaled = df.copy()

# %%
numeric_cols = df_scaled.select_dtypes(include=np.number).columns

# %%
scaler = StandardScaler()

df_scaled[numeric_cols] = scaler.fit_transform(
    df_scaled[numeric_cols]
)

# %%
df_scaled.head()
# Out:
#         Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  0.446350       Yes      Travel_Rarely   0.742527                   Sales
# 1  1.322365        No  Travel_Frequently  -1.297775  Research & Development
# 2  0.008343       Yes      Travel_Rarely   1.414363  Research & Development
# 3 -0.429664        No  Travel_Frequently   1.461466  Research & Development
# 4 -1.086676        No      Travel_Rarely  -0.524295  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0         -1.010909  -0.891688  Life Sciences            0.0       -1.701283
# 1         -0.147150  -1.868426  Life Sciences            0.0       -1.699621
# 2         -0.887515  -0.891688          Other            0.0       -1.696298
# 3         -0.764121   1.061787  Life Sciences            0.0       -1.694636
# 4         -0.887515  -1.868426        Medical            0.0       -1.691313
#
# ...

# %%
df["AgeGroup"] = pd.cut(
    df["Age"],
    bins=[0, 25, 35, 50, 100],
    labels=["Young", "Adult", "Middle_Aged", "Senior"]
)

# %%
df[["Age", "AgeGroup"]].head(10)
# Out:
#    Age     AgeGroup
# 0   41  Middle_Aged
# 1   49  Middle_Aged
# 2   37  Middle_Aged
# 3   33        Adult
# 4   27        Adult
# 5   32        Adult
# 6   59       Senior
# 7   30        Adult
# 8   38  Middle_Aged
# 9   36  Middle_Aged

# %%
df["IncomeCategory"] = pd.cut(
    df["MonthlyIncome"],
    bins=[0, 3000, 7000, 15000, np.inf],
    labels=["Low", "Medium", "High", "Very_High"]
)

# %%
df[["MonthlyIncome", "IncomeCategory"]].head(10)
# Out:
#    MonthlyIncome IncomeCategory
# 0           5993         Medium
# 1           5130         Medium
# 2           2090            Low
# 3           2909            Low
# 4           3468         Medium
# 5           3068         Medium
# 6           2670            Low
# 7           2693            Low
# 8           9526           High
# 9           5237         Medium

# %%
print("Final shape:", df.shape)
# Out:
# Final shape: (1470, 37)

# %%
print("Missing values:")
print(df.isnull().sum().sum())
# Out:
# Missing values:
# 0

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
df.to_csv(
    "IBM-HR-Data-Preprocessing/data/cleaned_IBM_HR_Employee_Attrition.csv",
    index=False
)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
import os

print(os.listdir("IBM-HR-Data-Preprocessing/data"))
# Out:
# ['cleaned_IBM_HR_Employee_Attrition.csv', 'WA_Fn-UseC_-HR-Employee-Attrition.csv']
